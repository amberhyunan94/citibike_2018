# %%
# Add dependencies
import glob
import pandas as pd

# %%
# Use glob to grab data in the same naming convention & concat the data & then use pd to create dataframes
clean_data_ridership = pd.concat([pd.read_csv(f) for f in glob.glob('raw_data/CitiBikeDailyRidershipandMembershipData/*.csv')], ignore_index = True, sort=False)
clean_data_trip = pd.concat([pd.read_csv(f) for f in glob.glob('raw_data/CitiBikeTripHistories/*.csv')], ignore_index = True,sort=False)

# %%
clean_data_ridership.head(10)
# Out:
#       Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0   4/1/18                                              33148
# 1   4/2/18                                              22062
# 2   4/3/18                                              25883
# 3   4/4/18                                              36755
# 4   4/5/18                                              39814
# 5   4/6/18                                              35624
# 6   4/7/18                                              33245
# 7   4/8/18                                              28410
# 8   4/9/18                                              40509
# 9  4/10/18                                              43051
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        94040
# 1                                        50418
# 2                                        59477
# 3                                        80049
# ...

# %%
clean_data_ridership.count()
# Out:
# Date                                                  365
# Trips over the past 24-hours (midnight to 11:59pm)    365
# Miles traveled today (midnight to 11:59 pm)           365
# Total Annual Members (All Time)                       365
# 24-Hour Passes Purchased (midnight to 11:59 pm)       365
# 3-Day Passes Purchased (midnight to 11:59 pm)         365
# dtype: int64

# %%
clean_data_trip.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1635  2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340
# 1           132  2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810
# 2          3337  2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470
# 3           436  2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830
# 4          8457  2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080
#
#    start station id               start station name  start station latitude  \
# 0             252.0     MacDougal St & Washington Sq               40.732264
# 1             314.0  Cadman Plaza West & Montague St               40.693830
# 2            3142.0                  1 Ave & E 62 St               40.761227
# 3             308.0          St James Pl & Oliver St               40.713079
# 4             345.0                  W 13 St & 6 Ave               40.736494
#
#    start station longitude  end station id            end station name  \
# ...

# %%
clean_data_trip.count()
# Out:
# tripduration               17548339
# starttime                  17548339
# stoptime                   17548339
# start station id           17545842
# start station name         17545842
# start station latitude     17548339
# start station longitude    17548339
# end station id             17545842
# end station name           17545842
# end station latitude       17548339
# end station longitude      17548339
# bikeid                     17548339
# usertype                   17548339
# birth year                 17548339
# gender                     17548339
# dtype: int64

# %%
# Export to csv
clean_data_ridership.to_csv("clean_data/clean_quarter_data_2018.csv")
clean_data_trip.to_csv("clean_data/clean_data_2018.csv")
